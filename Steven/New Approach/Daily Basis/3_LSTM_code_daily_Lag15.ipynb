# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import yfinance as yf
import datetime

# %% [markdown]
# ## Import data

# %%
start_date = datetime.datetime(2018, 1, 1)
end_date = datetime.datetime(2024, 1, 1)
btc_info = yf.Ticker("BTC-USD")

# pass the parameters as the taken dates for start and end
df = btc_info.history(start = start_date, end = end_date)

# %%
df.head()
# Out:
#                                    Open          High           Low  \
# Date
# 2018-01-01 00:00:00+00:00  14112.200195  14112.200195  13154.700195
# 2018-01-02 00:00:00+00:00  13625.000000  15444.599609  13163.599609
# 2018-01-03 00:00:00+00:00  14978.200195  15572.799805  14844.500000
# 2018-01-04 00:00:00+00:00  15270.700195  15739.700195  14522.200195
# 2018-01-05 00:00:00+00:00  15477.200195  17705.199219  15202.799805
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2018-01-01 00:00:00+00:00  13657.200195  10291200000        0.0           0.0
# 2018-01-02 00:00:00+00:00  14982.099609  16846600192        0.0           0.0
# 2018-01-03 00:00:00+00:00  15201.000000  16871900160        0.0           0.0
# 2018-01-04 00:00:00+00:00  15599.200195  21783199744        0.0           0.0
# 2018-01-05 00:00:00+00:00  17429.500000  23840899072        0.0           0.0

# %%
df = df.drop(columns=['Dividends', 'Stock Splits'])

# %%
df.columns = ['open', 'high', 'low', 'close', 'vol']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2191 entries, 2018-01-01 00:00:00+00:00 to 2023-12-31 00:00:00+00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    2191 non-null   float64
#  1   high    2191 non-null   float64
#  2   low     2191 non-null   float64
#  3   close   2191 non-null   float64
#  4   vol     2191 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 102.7 KB

# %%
# Prepare the volume and price differences, normalize volume
BTC_vol = df["vol"].values
df_diff = df.diff().dropna()
df_diff["vol"] = np.log(1 + BTC_vol[:-1])

# %%
df_aligned = df.loc[df_diff.index]

# %%
# Train data
# Period : From start of 2018 to end of 2022
mask_train = (df_diff.index >= "2018-01-01") & (df_diff.index < "2023-01-01")
df_train = df_diff.loc[mask_train].copy()
train_close = df_aligned.loc[mask_train, "close"].values
df_train["Relative_Close"] = train_close / train_close[0]

# %%
# Test data
# Period : Whole 2023
mask_test = (df_diff.index >= "2023-01-01") & (df_diff.index < "2024-01-01")  # December 2018 for testing
df_test = df_diff.loc[mask_test].copy()
test_close = df_aligned.loc[mask_test, "close"].values
df_test["Relative_Close"] = test_close / train_close[0]

# %%
df_train.head()
# Out:
#                                   open         high          low        close  \
# Date
# 2018-01-02 00:00:00+00:00  -487.200195  1332.399414     8.899414  1324.899414
# 2018-01-03 00:00:00+00:00  1353.200195   128.200195  1680.900391   218.900391
# 2018-01-04 00:00:00+00:00   292.500000   166.900391  -322.299805   398.200195
# 2018-01-05 00:00:00+00:00   206.500000  1965.499023   680.599609  1830.299805
# 2018-01-06 00:00:00+00:00  1984.899414     7.201172  1561.799805    97.500000
#
#                                  vol  Relative_Close
# Date
# 2018-01-02 00:00:00+00:00  23.054555        1.000000
# 2018-01-03 00:00:00+00:00  23.547415        1.014611
# 2018-01-04 00:00:00+00:00  23.548915        1.041189
# 2018-01-05 00:00:00+00:00  23.804405        1.163355
# 2018-01-06 00:00:00+00:00  23.894668        1.169863

# %%
df_test.head()
# Out:
#                                  open        high         low       close  \
# Date
# 2023-01-01 00:00:00+00:00  -55.759766    1.453125    3.714844   77.583984
# 2023-01-02 00:00:00+00:00   77.595703  128.904297   50.994141   63.390625
# 2023-01-03 00:00:00+00:00   63.337891    1.103516   50.142578   -8.613281
# 2023-01-04 00:00:00+00:00   -8.642578  204.138672   45.392578  183.380859
# 2023-01-05 00:00:00+00:00  183.267578  -80.564453  122.519531  -26.501953
#
#                                  vol  Relative_Close
# Date
# 2023-01-01 00:00:00+00:00  23.142672        1.109663
# 2023-01-02 00:00:00+00:00  22.947280        1.113894
# 2023-01-03 00:00:00+00:00  23.216287        1.113319
# 2023-01-04 00:00:00+00:00  23.355376        1.125559
# 2023-01-05 00:00:00+00:00  23.636798        1.123790

# %%
# Generate dataset function
def generate_dataset(df, seq_len):
    X_list, y_list = [], []
    for i in range(len(df) - seq_len):
        X_list.append(df.iloc[i:(i+seq_len), :].values)
        y_list.append(df["close"].iloc[i + seq_len])
    return np.array(X_list), np.array(y_list)

# %%
LAG = 15

# %%
# Prepare training and test datasets
X_train, y_train = generate_dataset(df_train, LAG)
X_test, y_test = generate_dataset(pd.concat((df_train.iloc[-LAG:], df_test)), LAG)

# %%
# Model architecture
tf.keras.utils.set_random_seed(4002)

model = Sequential([
    LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X_train, y_train, epochs=20, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 46/46 [==============================] - 2s 10ms/step - loss: 1043543.6875 - val_loss: 1051975.7500
# Epoch 2/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1027011.2500 - val_loss: 1031858.8125
# Epoch 3/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1013493.9375 - val_loss: 1056531.8750
# Epoch 4/20
# 46/46 [==============================] - 0s 6ms/step - loss: 999384.6875 - val_loss: 1063470.6250
# Epoch 5/20
# 46/46 [==============================] - 0s 6ms/step - loss: 1006493.6875 - val_loss: 1052771.3750
# Epoch 6/20
# 46/46 [==============================] - 0s 5ms/step - loss: 991415.9375 - val_loss: 1081868.3750
# Epoch 7/20
# 46/46 [==============================] - 0s 5ms/step - loss: 997969.7500 - val_loss: 1075608.6250
# Epoch 8/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1000144.0000 - val_loss: 1062405.5000
# Epoch 9/20
# 46/46 [==============================] - 0s 5ms/step - loss: 998196.5000 - val_loss: 1053201.6250
# Epoch 10/20
# 46/46 [==============================] - 0s 5ms/step - loss: 997308.6250 - val_loss: 1064917.0000
# Epoch 11/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1003508.6250 - val_loss: 1077084.8750
# Epoch 12/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1019363.8750 - val_loss: 1085285.3750
# Epoch 13/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1002385.6875 - val_loss: 1069935.5000
# Epoch 14/20
# 46/46 [==============================] - 0s 5ms/step - loss: 1011974.2500 - val_loss: 1053194.0000
# Epoch 15/20
# 46/46 [==============================] - 0s 5ms/step - loss: 992836.6875 - val_loss: 1071541.5000
# Epoch 16/20
# 46/46 [==============================] - 0s 5ms/step - loss: 991567.6250 - val_loss: 1089955.5000
# Epoch 17/20
# 46/46 [==============================] - 0s 5ms/step - loss: 977162.9375 - val_loss: 1076931.8750
# Epoch 18/20
# 46/46 [==============================] - 0s 5ms/step - loss: 973022.6875 - val_loss: 1059519.1250
# Epoch 19/20
# 46/46 [==============================] - 0s 5ms/step - loss: 976087.3125 - val_loss: 1046068.9375
# Epoch 20/20
# 46/46 [==============================] - 0s 5ms/step - loss: 974230.5625 - val_loss: 1050355.1250

# %%
# Predict
predictions = model.predict(X_test)
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
# Evaluate
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions)
print(f'Test MSE: {mse}')
# Out:
# Test MSE: 431626.19896269374
